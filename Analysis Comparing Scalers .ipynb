# %% [markdown]
# Experimentation >> Shape of Data
# - Take a couple of datasets
# - Plot the histogram of the featues (in original scale)
# Histogram >> continous data
# Bar Plot/Count plot >> categorical / discrete data
#
#
# Rescale/Transform the features >>
# - Take StandardScalar(), MinMaxScaler(), Normalizer()
# sklearn.preprocessing.
#
# - After scaling, replot histogram these features
#
# - Intention to check whether the distrubution changes ??
# - shape of the distribution ?? if it changes drastically for which scaler ??

# %%
import numpy as np
import pandas as pd 
from sklearn.datasets import load_boston
from sklearn.datasets import load_iris
from sklearn.datasets import load_diabetes
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler, MinMaxScaler, Normalizer, RobustScaler

# %%
ds_1 = load_boston()
ds_2 = load_iris()
# ds_3 = load_diabetes()

# %%
print(ds_1.data.shape)
print(ds_2.data.shape)
# print(ds_3.data.shape)
type(ds_1)
# Out:
# (506, 13)
# (150, 4)
# sklearn.utils.Bunch

# %%
boston  = pd.DataFrame(ds_1.data)
iris  = pd.DataFrame(ds_2.data)
# dibetes  = pd.DataFrame(ds_3.data)

# %%
boston.info()
iris.info()
# dibetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 13 columns):
# 0     506 non-null float64
# 1     506 non-null float64
# 2     506 non-null float64
# 3     506 non-null float64
# 4     506 non-null float64
# 5     506 non-null float64
# 6     506 non-null float64
# 7     506 non-null float64
# 8     506 non-null float64
# 9     506 non-null float64
# 10    506 non-null float64
# 11    506 non-null float64
# 12    506 non-null float64
# dtypes: float64(13)
# memory usage: 51.5 KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
# 0    150 non-null float64
# 1    150 non-null float64
# 2    150 non-null float64
# 3    150 non-null float64
# dtypes: float64(4)
# memory usage: 4.8 KB

# %%
mm_scaler = MinMaxScaler()
ss_scaler = StandardScaler()
nor = Normalizer()
rs = RobustScaler()

# %%
# plt.figure(figsize = (30,15))
# for i in range(0,12):
#   plt.hist(boston[:i],bins = 20, label=i)
#   plt.legend()

# %%
# plt.figure(figsize = (25,8))
# for i in range(0,3):
#   plt.hist(iris[:i],bins = 5, label=i)
#   plt.legend()

# %%
plt.figure(figsize = (25,8))
ax1 = sns.countplot(x=0, data=iris, palette="Set3")

# %%
plt.figure(figsize = (25,8))
ax3 = sns.countplot(x=1, data=iris, palette="Set3")

# %%
plt.figure(figsize = (25,8))
ax = sns.countplot(x=2, data=iris, palette="Set3")

# %%
plt.figure(figsize = (25,8))
ax4 = sns.countplot(x=3, data=iris, palette="Set3")

# %%
plt.figure(figsize = (25,8))
ax0 = sns.barplot(data=iris, palette="Set3")

# %%
iris_minmax = mm_scaler.fit_transform(iris)

# %%
plt.figure(figsize = (25,8))
ax5 = sns.barplot(data=iris_minmax, palette="Set3")

# %%
axxx = sns.countplot(x =0)

# %%
 iris_nor =nor.fit_transform(iris)

# %%
plt.figure(figsize = (25,8))
ax6 = sns.barplot(data=iris_nor, palette="Set3")

# %%
iris_sss =ss_scaler.fit_transform(iris)
plt.figure(figsize = (25,8))
ax7 = sns.barplot(data=iris_sss, palette="Set3")

# %%
iris_rs = rs.fit_transform(iris)
plt.figure(figsize = (25,8))
ax3 = sns.barplot(data=iris_rs, palette="Set3")

# %%
plt.figure(figsize = (25,8))
ax8 = sns.barplot(data=boston, palette="Set3")

# %%
boston_minmax = mm_scaler.fit_transform(boston)
plt.figure(figsize = (25,8))
ax9 = sns.barplot(data=boston_minmax, palette="Set3")

# %%
boston_nor =nor.fit_transform(boston)
plt.figure(figsize = (25,8))
ax10 = sns.barplot(data=boston_nor, palette="Set3")

# %%
boston_sss =ss_scaler.fit_transform(boston)
plt.figure(figsize = (25,8))
ax11 = sns.barplot(data=boston_sss, palette="Set3")

# %%
iris_rs = rs.fit_transform(iris)
plt.figure(figsize = (25,8))
ax3 = sns.barplot(data=iris_rs, palette="Set3")

# %% [markdown]
# ## **Analysis :** From here we can conclude that normalization maintain the data structure just limit the level.
#
#
# ## But on the other hand minmax, makes the all the features with same weight, makes the distribution constant.
#
# ## and standardscaler, align the data with zero line data distributed on both side of zero line.
